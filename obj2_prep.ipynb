# %%
from itertools import product
from pathlib import Path
import json


fold_ids = list(range(25))
sizes = [0.025, 0.05, 0.1, 0.25, 0.5, 0.75, 1]
prods = list(product(fold_ids, sizes))
len(prods)
# Out:
# 175

# %%
with Path("obj2_ids.json").open("w") as f:
    json.dump(prods, f)
