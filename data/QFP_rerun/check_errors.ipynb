# %%
import pandas as pd
import json
from pathlib import Path
from ml_enhance import QuantumFPFileLoader
from IPython.display import display

# %%
with open("error_batches.json", "r") as f:
    errors = json.load(f)

error_ids = list(map(lambda dic: dic["Id"], errors))
error_ids
# Out:
# [1226, 1517, 1611, 2094, 3236, 3241, 4053, 4382, 4441, 5262, 5882]

# %%
1226, 1611, 2094, 5262, 5882

# %%
with open("QFP_input_rerun.json", "r") as f:
    rerun_inputs = json.load(f)["inputs"]

error_smiles = list(filter(lambda input: input["id"] in error_ids, rerun_inputs))

# %%
error_smiles
# Out:
# [{'id': 1226, 'smiles': '[N:1]12[Si:2]34[N:3]5[Si:4]16[N:5]3[Si:6]25[N:7]46'},
#  {'id': 1517,
#   'smiles': '[N:1]([C:2](=[O:3])[C:4]([C:5]([C@:6]([N:7]([C:8](=[O:9])[C:10]([N+:11]([H:25])([H:26])[H:27])([H:23])[H:24])[H:22])([C:12]([O-:13])=[O:14])[H:21])([H:19])[H:20])([H:17])[H:18])([H:15])[H:16]'},
#  {'id': 1611,
#   'smiles': '[N+:1]([C@@:2]([C:3]([O-:4])=[O:5])([c:6]1[c:7]([H:16])[c:8]([H:17])[c:9]([H:18])[c:10]([H:19])[c:11]1[H:20])[H:15])([H:12])([H:13])[H:14]'},
#  {'id': 2094,
#   'smiles': '[N+:1]([C:2]([C:3]([C:4]([C:5]([C:6]([C:7]([C:8]([C:9]([C:10]([C:11]([C:12]([C:13]([O-:14])=[O:15])([H:39])[H:40])([H:37])[H:38])([H:35])[H:36])([H:33])[H:34])([H:31])[H:32])([H:29])[H:30])([H:27])[H:28])([H:25])[H:26])([H:23])[H:24])([H:21])[H:22])([H:19])[H:20])([H:16])([H:17])[H:18]'},
#  {'id': 3236,
# ...

# %%
loader = QuantumFPFileLoader(Path("../QuantumFP/QFP_output"))
filelist = loader.list_output_files()
filtered_list = list(filter(lambda path: any(str(num) in path.name for num in error_ids), filelist))

# %%
list(filter(lambda path: any(str(num) in path.name for num in [1226, 1611, 2094, 5262, 5882]), filelist))
# Out:
# []

# %%
filtered_list
# Out:
# [WindowsPath('../QuantumFP/QFP_output/internship_smiles2_1517.json.gz'),
#  WindowsPath('../QuantumFP/QFP_output/internship_smiles2_3236.json.gz'),
#  WindowsPath('../QuantumFP/QFP_output/internship_smiles2_3241.json.gz'),
#  WindowsPath('../QuantumFP/QFP_output/internship_smiles2_4053.json.gz'),
#  WindowsPath('../QuantumFP/QFP_output/internship_smiles2_4382.json.gz'),
#  WindowsPath('../QuantumFP/QFP_output/internship_smiles2_4441.json.gz')]

# %%
for df in loader.stream_conformer_dataframe(filtered_list[2]):
    display(df.loc[0, "original_smiles"])
    display(df["output_smiles"].values)
# Out:
# '[O:1]([C:2]([O:3][H:16])=[C:4]1[O:5][C:6]([C:12]([O:13][H:18])=[O:14])=[C:7]([H:17])[C:8](=[O:9])[C:10]1=[O:11])[H:15]'
# <StringArray>
# ['[O-:1][C:2]([O-:3])=[C:4]1[O:5][C:6]([C:12]([O-:13])=[O:14])=[C:7]([H:17])[C:8](=[O:9])[C:10]1=[O:11]', '[O:1]([C:2]([O:3][H:16])=[C:4]1[O:5][C:6]([C:12]([O:13][H:18])=[O:14])=[C:7]([H:17])[C:8](=[O:9])[C:10]1=[O:11])[H:15]']
# Length: 2, dtype: string

# %%
'[N:1]([C:2](=[O:3])[C:4]([C:5]([C@:6]([N:7]([C:8](=[O:9])[C:10]([N+:11]([H:25])([H:26])[H:27])([H:23])[H:24])[H:22])([C:12]([O-:13])=[O:14])[H:21])([H:19])[H:20])([H:17])[H:18])([H:15])[H:16]'

['[N:1]([C:2](=[O:3])[C:4]([C:5]([C@:6]([N:7]([C:8](=[O:9])[C:10]([