# %%
from ml_enhance import QuantumFPDatasetBuilder, QuantumFPFileLoader
from pathlib import Path
from rdkit import Chem
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
QFP_OUTPUT_PATH = Path("data/QuantumFP/QFP_output")
loader = QuantumFPFileLoader(QFP_OUTPUT_PATH)
builder = QuantumFPDatasetBuilder(QFP_OUTPUT_PATH)
output_files = loader.list_output_files()

# %%
df, error = builder.build_dataset_batched(files_list=output_files[:100])
# Out:
# 100%|██████████| 20/20 [00:27<00:00,  1.38s/it]

# %%
builder.build_single_molecule(output_files[0])

# %%
df.columns
# Out:
# Index(['id', 'atomization_energy', 'homo_lumo_gap', 'ionization_energy',
#        'electron_affinity', 'chemical_potential', 'molecular_dipole_norm',
#        'molecular_quadrupole_principal_invariant_2',
#        'molecular_quadrupole_principal_invariant_3',
#        'molecular_polarizability_mean',
#        ...
#        'avg_atomic_dipole_dipole_interaction',
#        'min_atomic_dipole_dipole_interaction',
#        'max_atomic_dipole_dipole_interaction',
#        'std_atomic_dipole_dipole_interaction', 'avg_bond_energy',
#        'min_bond_energy', 'max_bond_energy', 'std_bond_energy',
#        'num_heavy_H_bonds', 'smiles'],
#       dtype='str', length=129)

# %%
df
# Out:
#         id  atomization_energy  homo_lumo_gap  ionization_energy  \
# 0      0.0            5.239994       0.089513           0.476438
# 1      1.0            3.330826       0.105979           0.507545
# 2     10.0            7.140100       0.154440           0.463887
# 3    100.0            5.850939       0.073945           0.299042
# 4   1000.0            8.519924       0.068689           0.479849
# ..     ...                 ...            ...                ...
# 95  1083.0            1.846297       0.046618           0.630513
# 96  1084.0           13.554039       0.113665           0.459688
# 97  1085.0            8.848879       0.118578           0.439860
# 98  1086.0            9.536507       0.065824           0.318574
# 99  1087.0            6.838708       0.132274           0.551824
#
#     electron_affinity  chemical_potential  molecular_dipole_norm  \
# 0            0.201907           -0.338539               1.513984
# 1            0.200001           -0.356143               0.965182
# 2            0.109782           -0.296101               0.909688
# 3            0.004866           -0.145684               5.103982
# 4            0.249515           -0.373551               2.145071
# ..                ...                 ...                    ...
# 95           0.331759           -0.479713               3.325198
# 96           0.225525           -0.340364               1.581259
# 97           0.162004           -0.304885               0.969934
# 98           0.080840           -0.191154               5.057698
# 99           0.248525           -0.404076               1.382555
#
#     molecular_quadrupole_principal_invariant_2  \
# 0                                  -191.687655
# 1                                  -188.636399
# 2                                  -169.958738
# 3                                 -1306.769545
# 4                                  -670.362641
# ..                                         ...
# 95                                 -215.804240
# 96                                -1059.851722
# 97                                 -250.465623
# 98                                 -875.689933
# 99                                 -779.775757
#
#     molecular_quadrupole_principal_invariant_3  molecular_polarizability_mean  \
# 0                                   -37.755113                     -99.744189
# 1                                   720.869344                     -95.248037
# 2                                   291.625442                     -98.287723
# 3                                 16565.487506                     -90.301117
# 4                                 -1839.250752                    -230.053983
# ..                                         ...                            ...
# 95                                  975.853553                     -59.497025
# 96                                -2716.656256                    -170.257140
# 97                                 -468.118672                    -152.245955
# 98                                 5284.294482                    -180.462144
# 99                                 1170.692112                     -94.240671
#
#     ...  avg_atomic_dipole_dipole_interaction  \
# 0   ...                              0.000243
# 1   ...                              0.000551
# 2   ...                              0.000705
# 3   ...                              0.000501
# 4   ...                              0.000392
# ..  ...                                   ...
# 95  ...                             -0.002399
# 96  ...                              0.000344
# 97  ...                              0.000179
# 98  ...                              0.000066
# 99  ...                              0.000813
#
#     min_atomic_dipole_dipole_interaction  \
# 0                              -0.004885
# 1                              -0.005185
# 2                              -0.007544
# 3                              -0.005669
# 4                              -0.015509
# ..                                   ...
# 95                             -0.046310
# 96                             -0.014951
# 97                             -0.010610
# 98                             -0.009806
# 99                             -0.003924
#
#     max_atomic_dipole_dipole_interaction  \
# 0                               0.008604
# 1                               0.013913
# 2                               0.045773
# 3                               0.025149
# 4                               0.026877
# ..                                   ...
# 95                              0.012396
# 96                              0.026893
# 97                              0.031264
# 98                              0.015753
# 99                              0.027550
#
#     std_atomic_dipole_dipole_interaction  avg_bond_energy  min_bond_energy  \
# 0                               0.001218         0.211958         0.195515
# 1                               0.002770         0.209662         0.185616
# 2                               0.004067         0.210992         0.189256
# 3                               0.002806         0.201753         0.190508
# 4                               0.002881         0.212419         0.188283
# ..                                   ...              ...              ...
# 95                              0.011829         0.000000         0.000000
# 96                              0.003063         0.206542         0.192488
# 97                              0.002185         0.207787         0.186567
# 98                              0.000876         0.210019         0.206814
# 99                              0.004196         0.196771         0.193681
#
#     max_bond_energy  std_bond_energy  num_heavy_H_bonds  \
# 0          0.215375         0.007270           7.000000
# 1          0.217335         0.013488           5.000000
# 2          0.216436         0.007942          18.000000
# 3          0.212553         0.008140          11.000022
# 4          0.219220         0.009107          10.000000
# ..              ...              ...                ...
# 95         0.000000         0.000000           0.000000
# 96         0.218967         0.008235          32.000000
# 97         0.216710         0.010777          15.000000
# 98         0.215472         0.002434          13.000049
# 99         0.202305         0.003856           8.000000
#
#                                                smiles
# 0   [O:1]=[C:2]1[N:3]([H:14])[c:4]2[c:5]([H:15])[c...
# 1   [Cl:1][c:2]1[c:3]([H:10])[c:4]([H:11])[c:5]([C...
# 2   [C:1]([C:2]([C:3]([H:19])([H:20])[H:21])([C:4]...
# 3   [C:1]([c:2]1[c:3]([H:17])[c:4]([H:18])[c:5]([H...
# 4   [C:1]([O:2][C:3](=[O:4])[c:5]1[c:6]([H:28])[c:...
# ..                                                ...
# 95        [O:1]=[V:2](=[O:3])[O:4][V:5](=[O:6])=[O:7]
# 96  [C:1]([C:2]([C:3]([C:4]([O:5][C:6]([C:7]([O:8]...
# 97  [O:1]([c:2]1[c:3]([H:23])[c:4]([H:24])[c:5]([C...
# 98  [O:1]([C:2](=[O:3])[c:4]1[c:5]([H:25])[c:6]([H...
# 99  [O-:1][N+:2](=[O:3])[N:4]1[C:5]([H:21])([H:22]...
#
# [100 rows x 129 columns]

# %%
filtered = df.filter(regex="std")
filtered

# %%
filtered["smiles"].tolist()

# %%
['[O:1]=[C:2]1[N:3]([H:14])[c:4]2[c:5]([H:15])[c:6]([H:16])[c:7]([H:17])[c:8]3[c:9]([H:18])[c:10]([H:19])[c:11]([H:20])[c:12]1[c:13]23',
 '[Cl:1][c:2]1[c:3]([H:10])[c:4]([H:11])[c:5]([C:6](=[O:7])[H:12])[c:8]([H:13])[c:9]1[H:14]',
 '[C:1]([C:2]([C:3]([H:19])([H:20])[H:21])([C:4]([H:22])([H:23])[H:24])[c:5]1[c:6]([H:25])[c:7]([H:26])[c:8]([O:9][C:10]([C:11]2([H:29])[C:12]([H:30])([H:31])[O:13]2)([H:27])[H:28])[c:14]([H:32])[c:15]1[H:33])([H:16])([H:17])[H:18]',
 '[C:1]([c:2]1[c:3]([H:17])[c:4]([H:18])[c:5]([H:19])[c:6]([C:7]([H:20])([H:21])[H:22])[c:8]1[O:9][C:10]([C:11]([O:12][H:25])=[O:13])([H:23])[H:24])([H:14])([H:15])[H:16]',
 '[C:1]([O:2][C:3](=[O:4])[c:5]1[c:6]([H:28])[c:7]([H:29])[c:8]([C:14](=[O:15])[N:16]([c:17]2[c:18]([H:32])[c:19]([Cl:20])[c:21]([H:33])[c:22]([H:34])[c:23]2[Cl:24])[H:31])[c:9]([H:30])[c:10]1[N+:11]([O-:12])=[O:13])([H:25])([H:26])[H:27]']

# %%
[1, 2, 3] + [4, 5, 6]
