# %%
from ml_enhance import QuantumFPFileLoader, QFPFeatureEngineer, ConformerAggregator, QuantumFPDatasetBuilder, RDKitFeatureCalculator
from pathlib import Path
from rdkit import Chem
import pandas as pd
import numpy as np
import json
import os

# %%
OUTPUT_PATH = Path("../data/QuantumFP/QFP_output")

loader = QuantumFPFileLoader(OUTPUT_PATH)
output_files = loader.list_output_files()
output_files_numbers: list[Path] = [int(path.name.split('.')[0].split('_')[-1]) for path in output_files]

# %%
print(output_files)
# Out:
# [WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_0.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_10.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_100.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1000.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1001.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1002.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1003.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1004.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1005.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1006.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1007.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1008.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1009.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_101.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1010.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1011.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1012.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1013.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1014.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1015.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1016.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1017.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1018.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1019.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_102.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1020.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1021.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1022.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1023.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1024.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1025.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1026.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1027.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1028.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1029.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_103.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1030.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1031.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1032.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1033.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1034.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1035.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1036.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1037.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1038.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1039.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_104.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1040.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1041.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1042.json.gz'), WindowsPath('../data/QuantumFP/QFP_output/internship_smiles2_1043.json.gz'), WindowsP ...

# %%
# builder = QuantumFPDatasetBuilder(OUTPUT_PATH)
# df, errors = builder.build_dataset(multiprocess=True)

# %%
df = pd.read_json('../data/temp_df.json', orient='split', compression='infer')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 8837 entries, 0 to 8836
# Data columns (total 56 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   smiles                                       8837 non-null   str
#  1   energy                                       8802 non-null   float64
#  2   atomization_energy                           8802 non-null   float64
#  3   homo_lumo_gap                                8802 non-null   float64
#  4   ionization_energy                            8802 non-null   float64
#  5   electron_affinity                            8802 non-null   float64
#  6   chemical_potential                           8802 non-null   float64
#  7   molecular_dipole_norm                        8802 non-null   float64
#  8   molecular_quadrupole_principal_invariant_2   8802 non-null   float64
#  9   molecular_quadrupole_principal_invariant_3   8802 non-null   float64
#  10  molecular_polarizability_mean                8802 non-null   float64
#  11  molecular_polarizability_anisotropy          8802 non-null   float64
#  12  enthalpy                                     8802 non-null   float64
#  13  zero_point_energy                            8802 non-null   float64
#  14  radius_of_gyration                           8802 non-null   float64
#  15  molecular_volume                             8802 non-null   float64
#  16  sterimol_L                                   8802 non-null   float64
#  17  sterimol_Bmin                                8798 non-null   float64
#  18  sterimol_Bmax                                8798 non-null   float64
#  19  molecular_sasa                               8802 non-null   float64
#  20  solvation_energy_water                       8802 non-null   float64
#  21  solvation_energy_thf                         8802 non-null   float64
#  22  solvation_energy_cyclohexane                 8802 non-null   float64
#  23  solvation_energy_dmso                        8802 non-null   float64
#  24  gibbs_free_energy_300K                       8802 non-null   float64
#  25  entropy_300K                                 8802 non-null   float64
#  26  heat_capacity_300K                           8802 non-null   float64
#  27  ir_centroid_freq_1500                        8802 non-null   float64
#  28  ir_norm_intensity_1500                       8802 non-null   float64
#  29  ir_centroid_freq_1500_2750                   8802 non-null   float64
#  30  ir_norm_intensity_1500_2750                  8802 non-null   float64
#  31  ir_centroid_freq_2750_4000                   8802 non-null   float64
#  32  ir_norm_intensity_2750_4000                  8802 non-null   float64
#  33  avg_effective_coordination_number            8802 non-null   float64
#  34  avg_atomic_polarizability_mean               8802 non-null   float64
#  35  avg_partial_charge_water                     8802 non-null   float64
#  36  avg_percentage_buried_volume                 8802 non-null   float64
#  37  avg_atomic_polarizability_anisotropy         8802 non-null   float64
#  38  avg_atomic_sasa                              8802 non-null   float64
#  39  avg_partial_charge_thf                       8802 non-null   float64
#  40  avg_atomic_quadrupole_principal_invariant_2  8802 non-null   float64
#  41  avg_partial_charge_cyclohexane               8802 non-null   float64
#  42  avg_partial_charge_dmso                      8802 non-null   float64
#  43  avg_atomic_fukui_minus                       8802 non-null   float64
#  44  avg_atomic_quadrupole_principal_invariant_3  8802 non-null   float64
#  45  avg_atomic_fukui_plus                        8802 non-null   float64
#  46  avg_partial_charge                           8802 non-null   float64
#  47  avg_atomic_dipole_norm                       8802 non-null   float64
#  48  avg_atomic_charge_dipole_interaction         8802 non-null   float64
#  49  avg_bond_stiffness                           8802 non-null   float64
#  50  avg_overlap_integral                         8802 non-null   float64
#  51  avg_bond_length                              8802 non-null   float64
#  52  avg_atomic_dipole_dipole_interaction         8802 non-null   float64
#  53  avg_nuclear_repulsion                        8802 non-null   float64
#  54  avg_atomic_charge_quadrupole_interaction     8802 non-null   float64
#  55  avg_bond_energy                              8660 non-null   float64
# dtypes: float64(55), str(1)
# memory usage: 3.8 MB

# %%
df["avg_bond_energy"].to_list()
# Out:
# [0.2119584622,
#  0.2096624354,
#  0.2109920016,
#  0.201753446,
#  0.2124189374,
#  0.20784756980000002,
#  0.2111007893,
#  0.2133261166,
#  0.2077492272,
#  0.21422442500000002,
#  0.2075026087,
#  0.2063956837,
#  0.2104178146,
#  0.2067709388,
#  0.207569006,
#  0.2130992234,
#  0.2079637994,
#  0.2136708463,
#  0.213456065,
#  0.2108912685,
#  0.20631788750000002,
#  0.20857224600000002,
#  0.208341345,
#  0.20705525630000002,
#  0.20938877220000002,
#  0.20455514400000002,
#  0.2071807644,
#  0.2071462547,
#  0.1922158131,
#  0.2116867654,
#  0.2094859909,
#  0.2131719792,
#  0.2079203992,
#  0.21259866,
#  0.19803961320000002,
#  0.2114040886,
#  0.2075424505,
#  0.2064506689,
#  0.2001408701,
#  0.20740405050000002,
#  0.2148533372,
#  0.20828075410000002,
#  0.2126709114,
#  0.2111743932,
#  0.2118369128,
#  0.21159952680000002,
#  0.2200104379,
#  0.2044300939,
#  0.2051234349,
#  0.2072248313,
#  0.2085442904,
#  0.20559203510000001,
#  0.2115678625,
#  0.2083538403,
#  0.2136110889,
#  0.2125690767,
#  0.204914739,
#  0.2098990764,
#  0.1949228221,
#  0.2122847246,
#  0.2135429762,
#  0.2070567784,
#  0.1976705852,
#  0.2083460262,
#  0.21214201030000002,
#  0.2087306971,
#  0.2095797274,
#  0.2127439388,
#  0.2074671207,
#  nan,
#  0.2115186023,
#  0.21218483840000002,
#  0.1971134085,
#  0.1764240676,
#  0.2084318259,
#  0.2049451099,
#  0.19626721960000001,
#  0.21152547430000002,
#  0.2092203686,
#  0.21045312900000002,
#  0.209866204,
#  0.2011729663,
#  0.20455890740000002,
#  0.20881808270000002,
#  0.21004598530000002,
#  0.2096834531,
#  0.2085360661,
#  0.20793333600000002,
#  0.20724235030000002,
#  0.2069017302,
#  0.2135441862,
#  0.2010189483,
#  0.20723047760000002,
#  0.20823652650000002,
#  0.2098669991,
#  nan,
#  0.2065418943,
#  0.20778718640000002,
#  0.2100190334,
#  0.19677126690000002,
#  0.2131405144,
#  0.17606483050000002,
#  0.208064556,
#  0.21754456860000002,
#  0.21098350440000002,
#  nan,
#  0.2126698787,
#  0.20940972430000002,
#  0.2144286853,
#  0.20874320070000002,
#  0.20904840090000001,
#  0.2115775688,
#  0.2084847804,
#  0.2071458705,
#  0.21211589020000002,
#  0.2083276149,
#  0.2089568956,
#  0.2069544251,
#  0.20097155160000002,
#  0.2069112501,
#  0.2165859746,
#  nan,
#  0.2086548603,
#  0.20775050220000002,
#  0.2106873361,
#  0.2126766447,
#  0.2089642867,
#  0.21286282950000002,
#  0.2144138874,
#  0.20084034420000002,
#  0.20666024830000002,
#  0.1797071004,
#  nan,
#  0.2101632575,
#  0.21080781,
#  0.2071946844,
#  0.20818239430000002,
#  0.2065573753,
#  0.20116555200000003,
#  0.2051689858,
#  0.2040097927,
#  0.20092002220000002,
#  0.2126294983,
#  0.209587495,
#  0.2080769603,
#  0.2102906953,
#  0.2090553422,
#  0.21222547460000002,
#  0.2055065197,
#  0.2059361969,
#  0.2084130294,
#  0.2073686139,
#  0.2072767099,
#  0.204376,
#  0.1244951728,
#  0.2077850846,
#  0.2093953145,
#  0.21332132650000002,
#  nan,
#  0.2108701084,
#  0.2061381197,
#  0.2053680455,
#  0.2130254798,
#  0.2060320987,
#  0.2056494825,
#  0.1950251244,
#  0.2102617552,
#  0.2061967396,
#  0.21330130060000002,
#  0.2094512467,
#  0.2033969696,
#  0.2058678306,
#  0.2068399363,
#  0.20664131770000002,
#  0.2069375641,
#  0.2146596764,
#  0.2072245012,
#  0.2072391488,
#  0.1484124862,
#  0.2115948533,
#  0.1888046206,
#  0.2080709402,
#  0.2108648318,
#  0.205953786,
#  0.2070208751,
#  0.2001677705,
#  0.20807521950000002,
#  0.20282158390000002,
#  nan,
#  0.2083587211,
#  0.20592239410000002,
#  0.1999508301,
#  -0.0282631687,
#  0.2081585722,
#  0.2115427303,
#  0.2085837778,
#  0.2122605723,
#  0.20896608220000001,
#  0.2085521549,
#  0.21398047580000001,
#  0.2074978918,
#  0.2012440232,
#  0.2062191992,
#  0.2126347347,
#  0.21030394530000002,
#  0.2080568053,
#  0.21171058210000002,
#  nan,
#  0.2082558948,
#  0.2053490151,
#  0.210352592,
#  0.20814321400000002,
#  0.20352597800000002,
#  0.2126761697,
#  0.2084782848,
#  0.2077521413,
#  0.207459248,
#  0.2076453114,
#  0.20809170970000002,
#  0.21314959160000002,
#  0.2109051857,
#  0.20749424100000002,
#  nan,
#  0.20774120710000002,
#  0.2053369002,
#  0.20904165660000001,
#  0.2155774211,
#  0.2142014553,
#  0.217627973,
#  0.2091043103,
#  0.2086289896,
#  0.20764549770000001,
#  0.20745031060000002,
#  0.2097190018,
#  0.2080193625,
#  0.20680678500000002,
#  0.2086130933,
#  0.20755172360000002,
#  0.2077708239,
#  0.21007008570000002,
#  0.2074699619,
#  0.20949685910000002,
#  0.2094030811,
#  0.2059279024,
#  0.21126983840000002,
#  nan,
#  0.2091919947,
#  0.2104948842,
#  0.2039867501,
#  0.21657516400000001,
#  0.2074142742,
#  0.20006129920000001,
#  0.21141852360000002,
#  0.20957692420000001,
#  0.2111295674,
#  0.21148125480000002,
#  0.19984474130000002,
#  0.20931703610000002,
#  0.2105481528,
#  0.2129811892,
#  0.20963986810000002,
#  0.2096923922,
#  0.2037366549,
#  0.2082674515,
#  0.20926375100000003,
#  0.20810202560000002,
#  0.2089785027,
#  0.2162196922,
#  0.1993602334,
#  0.20948147020000002,
#  0.2084706811,
#  0.2091311991,
#  0.2148437172,
#  0.2084868708,
#  nan,
#  0.2152974486,
#  0.2074221859,
#  0.2131292877,
#  0.2099174,
#  0.2096585627,
#  0.2090687944,
#  0.2090248469,
#  0.20915151540000002,
#  0.2080075721,
#  0.2081123132,
#  0.21142059940000002,
#  0.2082243778,
#  0.2080686262,
#  0.215292491,
#  nan,
#  0.20648135750000002,
#  0.21221049700000003,
#  0.2065984592,
#  0.1945770271,
#  0.21038076690000002,
#  0.20771713120000002,
#  0.2085718313,
#  0.209846947,
#  0.2087138806,
#  0.2107411707,
#  0.2040365146,
#  0.2110300342,
#  0.2104586118,
#  0.206578331,
#  nan,
#  0.2064260979,
#  nan,
#  0.2089001013,
#  nan,
#  0.2098054305,
#  nan,
#  0.209224963,
#  0.2092637303,
#  nan,
#  0.20902578670000002,
#  nan,
#  0.20991527880000002,
#  0.2080093703,
#  0.20938573570000002,
#  nan,
#  0.20815439500000002,
#  0.2081319874,
#  0.2105790907,
#  0.2084848772,
#  0.2084703565,
#  nan,
#  nan,
#  0.2073784759,
#  0.2093121437,
#  0.2035745836,
#  0.2129806953,
#  0.2088442118,
#  0.2082361527,
#  0.2076364359,
#  0.2031370424,
#  0.20933183090000002,
#  nan,
#  0.2080999345,
#  0.2086941406,
#  0.20874895810000002,
#  0.20759451710000001,
#  nan,
#  0.2076668015,
#  0.2088892051,
#  0.2080776343,
#  0.20999550120000002,
#  0.2076940093,
#  0.2136474402,
#  0.21047640380000002,
#  0.2037776419,
#  0.2028118794,
#  0.2122709587,
#  0.2037833363,
#  0.2091277171,
#  0.209512792,
#  0.2094894763,
#  0.2097527763,
#  0.2066419052,
#  0.2097576458,
#  0.2099634091,
#  0.2116997573,
#  0.2041325713,
#  0.2074730194,
#  nan,
#  0.20691894660000001,
#  0.2122021845,
#  0.2078907774,
#  0.20807392260000002,
#  0.2178475701,
#  0.2097439848,
#  0.21195389520000002,
#  0.20651757040000002,
#  nan,
#  0.2071659258,
#  0.2077370386,
#  0.2090364243,
#  0.2101446304,
#  0.2102347705,
#  0.2156796833,
#  0.2108950885,
#  0.2123537476,
#  0.2072956592,
#  0.20761591170000002,
#  nan,
#  nan,
#  0.2123762905,
#  0.2105986729,
#  0.20317865540000002,
#  0.2060825618,
#  0.209115927,
#  0.2065462646,
#  0.2113129534,
#  0.2133407964,
#  0.2063783354,
#  0.2088699959,
#  0.2063079826,
#  nan,
#  0.2093323256,
#  0.20743980180000002,
#  0.1946383293,
#  0.2096037729,
#  0.2152097758,
#  0.20684808170000002,
#  0.1971955752,
#  0.19861270450000001,
#  0.2030024243,
#  0.2117317021,
#  0.1968501954,
#  0.20459017810000002,
#  0.2124985667,
#  0.20818003240000002,
#  0.2043365774,
#  0.206908018,
#  0.2098363093,
#  0.21920896620000002,
#  0.20593996520000002,
#  0.2096302717,
#  0.2113054541,
#  0.182878955,
#  0.2064832774,
#  0.203409358,
#  0.2077850931,
#  0.2057716731,
#  0.2078069003,
#  0.1862595981,
#  0.1986585432,
#  0.2004151077,
#  0.209509948,
#  0.1980275524,
#  0.2035740182,
#  0.2091249913,
#  0.17495563220000002,
#  0.2084561523,
#  0.2087002489,
#  0.2123864786,
#  0.2005544992,
#  0.2107457989,
#  0.2054991477,
#  0.2061730403,
#  0.20223628970000002,
#  0.1997838761,
#  nan,
#  0.20417310600000002,
#  0.2028364639,
#  0.1982435367,
#  0.2178175158,
#  0.2100702553,
#  0.2041957742,
#  0.2051174711,
#  0.2054898588,
#  0.2006302128,
#  0.2080153844,
#  0.20661267020000001,
#  nan,
#  0.20387708840000002,
#  0.19893926450000002,
#  0.2016253019,
#  nan,
#  0.2038954616,
#  0.21228779220000002,
#  0.20615307830000001,
#  0.1783234783,
#  0.2054284555,
#  0.21171576520000002,
#  0.1925317503,
#  0.20778480940000002,
#  0.1994513567,
#  0.2105171974,
#  0.2067670835,
#  0.21605540980000001,
#  0.2085499367,
#  0.1853585215,
#  0.2136045157,
#  0.20512834840000002,
#  0.2096687874,
#  0.2094908294,
#  0.17452979570000002,
#  0.2053024822,
#  0.2106152939,
#  0.2055177312,
#  0.2053604789,
#  0.2017014908,
#  0.1957297922,
#  0.197627945,
#  0.2006744282,
#  0.2136418454,
#  0.1972588308,
#  0.2041798758,
#  0.20091920630000001,
#  0.1996452055,
#  0.20115691800000002,
#  0.2083882423,
#  0.2055185394,
#  0.2095259578,
#  0.2062106577,
#  0.19757187140000002,
#  0.1862228447,
#  0.21429343580000002,
#  0.2047923486,
#  0.20099933550000001,
#  0.2105043043,
#  0.2095696527,
#  0.20470948260000002,
#  0.2090503354,
#  0.2133738242,
#  0.2036904723,
#  0.203491475,
#  0.2051030006,
#  0.19620577150000001,
#  0.20448952750000002,
#  0.21117323200000002,
#  0.2072208493,
#  0.2118321122,
#  0.20607329100000002,
#  0.2056281676,
#  0.2180232719,
#  0.2090261777,
#  0.2069393863,
#  0.2044037132,
#  0.2080513517,
#  0.2048597496,
#  0.2050536138,
#  0.2063429223,
#  0.2090284326,
#  0.1734359009,
#  0.20694765380000002,
#  0.1883157036,
#  0.2094003498,
#  0.20529160870000002,
#  0.2027588932,
#  0.2063200443,
#  0.2072049272,
#  0.200791919,
#  0.2021087248,
#  0.2035358575,
#  0.209900586,
#  0.2109744449,
#  0.21541888650000002,
#  0.2060413257,
#  0.201960415,
#  0.2015027829,
#  0.204035355,
#  0.20794409930000002,
#  0.2098276531,
#  0.2161516836,
#  0.2081121411,
#  0.2045466549,
#  0.20643130480000002,
#  0.21088264010000002,
#  0.1907804244,
#  0.2068859791,
#  0.20652397500000003,
#  0.2029933865,
#  0.2086079452,
#  0.2057163955,
#  0.2034180741,
#  0.2110069082,
#  0.20813073980000002,
#  0.2149604045,
#  0.2132990766,
#  0.20728345650000002,
#  0.2044813918,
#  0.2049440454,
#  0.20165205390000002,
#  0.2141737283,
#  0.20993914930000002,
#  0.1999119965,
#  0.2064216495,
#  0.2166032582,
#  0.19665837700000002,
#  0.2085428158,
#  0.20888552270000002,
#  0.20957249660000002,
#  0.2105780482,
#  nan,
#  0.20161397650000001,
#  0.19672633450000002,
#  0.2048242401,
#  0.2098648531,
#  0.2144812801,
#  0.213901695,
#  0.20659624170000002,
#  0.21312892800000002,
#  nan,
#  0.2159178918,
#  0.2063044867,
#  0.20974002630000002,
#  0.20454846670000001,
#  0.2018091494,
#  0.1892792469,
#  0.19821972610000002,
#  0.2128185257,
#  0.2136233135,
#  0.2046121247,
#  0.196255799,
#  0.1986107362,
#  0.2060926003,
#  0.20065503880000002,
#  0.2070585405,
#  0.1868508103,
#  0.1872607661,
#  nan,
#  0.2097790598,
#  0.2031427738,
#  0.2018261748,
#  0.2050430963,
#  0.198714269,
#  0.2084042815,
#  0.2035496615,
#  0.20871035340000002,
#  0.2094112811,
#  0.2078005896,
#  0.2106483986,
#  0.2079533336,
#  0.22603430700000002,
#  0.2135866147,
#  0.20786138950000002,
#  0.20577488770000002,
#  0.2062972412,
#  0.2104937125,
#  0.1918812919,
#  0.2057772047,
#  0.20032216260000002,
#  0.20774122020000002,
#  0.2154153789,
#  0.2088108512,
#  0.2104317845,
#  0.20441233420000002,
#  0.20664923970000001,
#  0.2121088029,
#  0.2042240635,
#  0.2061067214,
#  0.2064901973,
#  0.2022908539,
#  0.2071816106,
#  0.1869170031,
#  0.2013045986,
#  nan,
#  0.21079373210000002,
#  0.20063436610000002,
#  0.1914541176,
#  0.2063753902,
#  0.1975159725,
#  0.21163006720000002,
#  0.2052153762,
#  0.2086982316,
#  0.20886926090000002,
#  0.2041473606,
#  0.2070192863,
#  0.1979046244,
#  0.2063234179,
#  0.20628016500000002,
#  0.2330897919,
#  0.1993503955,
#  0.2063334688,
#  0.20489710160000002,
#  0.20902369880000002,
#  0.20186870540000001,
#  0.2115140298,
#  0.20629278210000002,
#  0.2047968584,
#  0.2039732834,
#  0.2067018135,
#  0.1973308669,
#  0.2037796425,
#  0.2040848116,
#  0.2005556298,
#  0.2054009926,
#  0.20655703490000002,
#  0.20160265060000002,
#  0.20992139140000002,
#  0.2024369859,
#  0.207181931,
#  0.2205604516,
#  0.21136710890000002,
#  0.20586231230000002,
#  0.20990555060000002,
#  0.20964675630000001,
#  0.2066226897,
#  0.2070581803,
#  0.21171913120000002,
#  0.2122762946,
#  0.2086835481,
#  0.1734359009,
#  0.1768171953,
#  0.19796300800000002,
#  0.2053075872,
#  0.2090129487,
#  0.19801722430000002,
#  0.22411623590000002,
#  0.2084456022,
#  0.2072402247,
#  0.20957313930000002,
#  0.20846819700000002,
#  0.20503609490000002,
#  0.20434691400000002,
#  0.20660436410000002,
#  0.2097961626,
#  0.2113650825,
#  0.2055665734,
#  0.2097469432,
#  0.20402764810000001,
#  0.20542536050000001,
#  0.1983678146,
#  0.1998448247,
#  0.1978443148,
#  0.20306200500000002,
#  0.2008448477,
#  0.1986958618,
#  0.2131505604,
#  0.1856027533,
#  0.1931459163,
#  0.209864243,
#  0.2111266872,
#  0.2047130658,
#  0.20975950270000002,
#  0.2065013721,
#  0.20726947510000002,
#  0.20717374400000002,
#  0.20822719,
#  0.1919975136,
#  0.2012069175,
#  0.20990384210000002,
#  0.2075803418,
#  0.18549765470000001,
#  0.21036121060000001,
#  0.2100313416,
#  0.2057624352,
#  0.2068123633,
#  0.205325901,
#  0.2124445173,
#  0.21014619080000002,
#  0.2065758821,
#  0.20970652450000002,
#  0.1641593157,
#  0.21625052930000002,
#  0.2079338839,
#  0.2017191305,
#  0.2074854529,
#  0.1971996956,
#  0.2106297199,
#  0.2063842554,
#  0.20518647850000002,
#  0.20898858620000002,
#  0.2082565089,
#  0.1769829223,
#  0.191402849,
#  0.2031529775,
#  0.20222654580000002,
#  0.2122558128,
#  0.2013069046,
#  0.20157094490000002,
#  0.2086916006,
#  0.2088863688,
#  0.2117113113,
#  0.2003493732,
#  0.2031810172,
#  0.2057911046,
#  0.2087556097,
#  0.21368398870000002,
#  0.2125596877,
#  0.2117743524,
#  0.2065055576,
#  0.2068632061,
#  0.20515810080000002,
#  0.21275411430000002,
#  0.20808844310000002,
#  0.2037693123,
#  0.20612425920000002,
#  0.21017196500000002,
#  0.1908189462,
#  0.1959923386,
#  0.1945397871,
#  0.2152777945,
#  0.202331595,
#  0.20802576250000002,
#  0.2025501774,
#  0.2118220821,
#  0.2043352873,
#  0.2024276716,
#  0.2053224249,
#  0.2063341018,
#  0.2061284585,
#  0.20293325140000001,
#  0.2092581681,
#  nan,
#  0.202318088,
#  0.2088252744,
#  0.21087649930000002,
#  0.2110180596,
#  0.21374962620000001,
#  0.2094530061,
#  0.2068236672,
#  0.20746342750000002,
#  0.2049384018,
#  0.2088479098,
#  0.20582135510000002,
#  0.20786045220000002,
#  0.2059836592,
#  0.20794203830000002,
#  0.20903914810000002,
#  0.2053506772,
#  0.21120600150000002,
#  0.1778499135,
#  0.2114857439,
#  0.2101846337,
#  0.1907160117,
#  0.20993796650000002,
#  0.21146975280000002,
#  0.2176118661,
#  0.2042857586,
#  0.213540752,
#  0.21060919720000001,
#  0.19276719790000002,
#  0.20409116200000002,
#  0.19882650670000002,
#  0.2032448869,
#  0.2079592191,
#  0.2097377209,
#  0.2104781067,
#  0.1970064916,
#  0.202302905,
#  0.1956924908,
#  0.20972543700000001,
#  0.21743886880000002,
#  0.2073237011,
#  0.170944495,
#  0.20520056590000002,
#  0.1876493868,
#  0.209304444,
#  0.2084452634,
#  0.2103598901,
#  0.2027416672,
#  0.2008558392,
#  0.2124137698,
#  0.2097491444,
#  0.2090406294,
#  0.1986052029,
#  0.215044335,
#  0.20578981670000002,
#  0.2081783042,
#  0.2083003742,
#  0.2069368873,
#  0.2118754112,
#  0.2159151047,
#  0.1994643451,
#  0.2197457619,
#  0.20743286860000001,
#  0.1965867,
#  0.2042639416,
#  0.1834005702,
#  0.20585402360000002,
#  0.20639060680000001,
#  0.2078706117,
#  0.1981238831,
#  0.21625207970000002,
#  0.20690941670000002,
#  0.20434316430000002,
#  0.2087331286,
#  0.2039973148,
#  0.2080717258,
#  0.2058118588,
#  0.2084495067,
#  0.2078872502,
#  0.2024301132,
#  0.21025911020000002,
#  0.209033868,
#  0.2081812063,
#  0.2077901818,
#  0.2068525491,
#  0.21691239980000002,
#  0.20744554780000002,
#  0.2053400712,
#  0.2131250385,
#  0.2085866415,
#  0.2010858989,
#  0.2113463293,
#  0.21330074940000002,
#  0.2063835495,
#  0.2156492389,
#  0.2004189781,
#  0.2031518294,
#  0.20802467930000001,
#  0.202600934,
#  0.2119841022,
#  0.20595388380000001,
#  0.2091170591,
#  0.20497757400000002,
#  0.20718161400000001,
#  0.2107374445,
#  0.2059276941,
#  0.1961798035,
#  0.2020149256,
#  0.2057916461,
#  0.20725682650000002,
#  0.2124279577,
#  nan,
#  0.2062923094,
#  0.2112671103,
#  0.21153914270000002,
#  0.2081075129,
#  0.210354592,
#  0.20670107100000001,
#  0.1921838085,
#  0.2094912495,
#  0.2032915043,
#  0.2106953433,
#  0.1866802863,
#  0.2058087141,
#  0.20686413080000002,
#  0.2064663578,
#  0.2046908148,
#  0.2067730153,
#  0.19948203820000002,
#  0.21316546990000002,
#  0.2073556291,
#  0.2107814636,
#  0.1917789402,
#  0.205621872,
#  0.2062480263,
#  0.2085201637,
#  0.2082614281,
#  0.20696757070000002,
#  0.2038386557,
#  0.204711931,
#  0.2130975161,
#  0.1950845766,
#  0.21171271120000001,
#  0.2042008137,
#  0.20616811270000002,
#  0.2176914087,
#  0.2110974299,
#  0.2113250617,
#  0.20331709420000002,
#  0.21132427080000002,
#  0.21415492860000002,
#  0.2030231116,
#  0.2087879376,
#  0.2101862612,
#  0.20060253990000002,
#  0.2036269024,
#  0.20904100020000002,
#  0.20909882970000002,
#  0.1947152975,
#  0.2037226107,
#  0.20079472280000002,
#  0.20507953650000002,
#  0.1978830044,
#  0.206945614,
#  0.1876993952,
#  0.1888396681,
#  0.20162614610000001,
#  0.20936573,
#  0.20688646230000002,
#  0.1985890305,
#  0.2048281805,
#  0.2144672894,
#  0.17684047420000001,
#  0.2083670535,
#  0.2044324046,
#  0.2003351608,
#  0.2047192234,
#  0.2141526584,
#  0.2000773217,
#  0.2061301267,
#  0.2083533451,
#  0.2056541117,
#  0.20563656100000002,
#  0.2077546912,
#  0.208904908,
#  0.2044951072,
#  0.2057808257,
#  0.20470822190000001,
#  0.2019906348,
#  0.2059824227,
#  0.20824965950000002,
#  nan,
#  0.216979431,
#  0.2152944946,
#  0.1965162463,
#  0.20223870730000001,
#  0.1973565099,
#  0.2031934589,
#  0.20536317410000002,
#  0.19717882120000002,
#  0.2012493752,
#  0.2022353288,
#  0.20550567690000002,
#  0.1973098372,
#  0.1995318599,
#  0.2002798846,
#  0.1986633878,
#  0.20283596680000002,
#  0.19245713420000002,
#  0.2076528685,
#  0.210785678,
#  0.2181038562,
#  0.2137638641,
#  0.2071874253,
#  0.21120661100000002,
#  ...]

# %%
# df.to_json('../data/temp_df.json', orient='split', compression='infer', index=True)

# %%
df[df["smiles"]=="[F:1][C:2]([F:3])([F:4])[F:5]"]
# Out:
#                             smiles     energy  atomization_energy  \
# 105  [F:1][C:2]([F:3])([F:4])[F:5] -21.078563            0.803077
#
#      homo_lumo_gap  ionization_energy  electron_affinity  chemical_potential  \
# 105        0.66204            0.74286          -0.235545           -0.259115
#
#      molecular_dipole_norm  molecular_quadrupole_principal_invariant_2  \
# 105               0.000124                               -1.810000e-08
#
#      molecular_quadrupole_principal_invariant_3  ...  avg_partial_charge  \
# 105                                         0.0  ...                 0.0
#
#      avg_atomic_dipole_norm  avg_atomic_charge_dipole_interaction  \
# 105                0.240626                               0.01759
#
#      avg_bond_stiffness  avg_overlap_integral  avg_bond_length  \
# 105            0.671279              0.141857         2.483285
#
#      avg_atomic_dipole_dipole_interaction  avg_nuclear_repulsion  \
# 105                              0.009155              10.944868
#
#      avg_atomic_charge_quadrupole_interaction  avg_bond_energy
# 105                                  0.005217              NaN
#
# [1 rows x 56 columns]

# %%
df.isnull().sum()
# Out:
# smiles                                           0
# energy                                          35
# atomization_energy                              35
# homo_lumo_gap                                   35
# ionization_energy                               35
# electron_affinity                               35
# chemical_potential                              35
# molecular_dipole_norm                           35
# molecular_quadrupole_principal_invariant_2      35
# molecular_quadrupole_principal_invariant_3      35
# molecular_polarizability_mean                   35
# molecular_polarizability_anisotropy             35
# enthalpy                                        35
# zero_point_energy                               35
# radius_of_gyration                              35
# molecular_volume                                35
# sterimol_L                                      35
# sterimol_Bmin                                   39
# sterimol_Bmax                                   39
# molecular_sasa                                  35
# solvation_energy_water                          35
# solvation_energy_thf                            35
# solvation_energy_cyclohexane                    35
# solvation_energy_dmso                           35
# gibbs_free_energy_300K                          35
# entropy_300K                                    35
# heat_capacity_300K                              35
# ir_centroid_freq_1500                           35
# ir_norm_intensity_1500                          35
# ir_centroid_freq_1500_2750                      35
# ir_norm_intensity_1500_2750                     35
# ir_centroid_freq_2750_4000                      35
# ir_norm_intensity_2750_4000                     35
# avg_effective_coordination_number               35
# avg_atomic_polarizability_mean                  35
# avg_partial_charge_water                        35
# avg_percentage_buried_volume                    35
# avg_atomic_polarizability_anisotropy            35
# avg_atomic_sasa                                 35
# avg_partial_charge_thf                          35
# avg_atomic_quadrupole_principal_invariant_2     35
# avg_partial_charge_cyclohexane                  35
# avg_partial_charge_dmso                         35
# avg_atomic_fukui_minus                          35
# avg_atomic_quadrupole_principal_invariant_3     35
# avg_atomic_fukui_plus                           35
# avg_partial_charge                              35
# avg_atomic_dipole_norm                          35
# avg_atomic_charge_dipole_interaction            35
# avg_bond_stiffness                              35
# avg_overlap_integral                            35
# avg_bond_length                                 35
# avg_atomic_dipole_dipole_interaction            35
# avg_nuclear_repulsion                           35
# avg_atomic_charge_quadrupole_interaction        35
# avg_bond_energy                                177
# dtype: int64

# %%
null_df = df[df.isnull().any(axis=1)].reset_index()

# %%
null_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 57 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   index                                        177 non-null    int64
#  1   smiles                                       177 non-null    str
#  2   energy                                       142 non-null    float64
#  3   atomization_energy                           142 non-null    float64
#  4   homo_lumo_gap                                142 non-null    float64
#  5   ionization_energy                            142 non-null    float64
#  6   electron_affinity                            142 non-null    float64
#  7   chemical_potential                           142 non-null    float64
#  8   molecular_dipole_norm                        142 non-null    float64
#  9   molecular_quadrupole_principal_invariant_2   142 non-null    float64
#  10  molecular_quadrupole_principal_invariant_3   142 non-null    float64
#  11  molecular_polarizability_mean                142 non-null    float64
#  12  molecular_polarizability_anisotropy          142 non-null    float64
#  13  enthalpy                                     142 non-null    float64
#  14  zero_point_energy                            142 non-null    float64
#  15  radius_of_gyration                           142 non-null    float64
#  16  molecular_volume                             142 non-null    float64
#  17  sterimol_L                                   142 non-null    float64
#  18  sterimol_Bmin                                138 non-null    float64
#  19  sterimol_Bmax                                138 non-null    float64
#  20  molecular_sasa                               142 non-null    float64
#  21  solvation_energy_water                       142 non-null    float64
#  22  solvation_energy_thf                         142 non-null    float64
#  23  solvation_energy_cyclohexane                 142 non-null    float64
#  24  solvation_energy_dmso                        142 non-null    float64
#  25  gibbs_free_energy_300K                       142 non-null    float64
#  26  entropy_300K                                 142 non-null    float64
#  27  heat_capacity_300K                           142 non-null    float64
#  28  ir_centroid_freq_1500                        142 non-null    float64
#  29  ir_norm_intensity_1500                       142 non-null    float64
#  30  ir_centroid_freq_1500_2750                   142 non-null    float64
#  31  ir_norm_intensity_1500_2750                  142 non-null    float64
#  32  ir_centroid_freq_2750_4000                   142 non-null    float64
#  33  ir_norm_intensity_2750_4000                  142 non-null    float64
#  34  avg_effective_coordination_number            142 non-null    float64
#  35  avg_atomic_polarizability_mean               142 non-null    float64
#  36  avg_partial_charge_water                     142 non-null    float64
#  37  avg_percentage_buried_volume                 142 non-null    float64
#  38  avg_atomic_polarizability_anisotropy         142 non-null    float64
#  39  avg_atomic_sasa                              142 non-null    float64
#  40  avg_partial_charge_thf                       142 non-null    float64
#  41  avg_atomic_quadrupole_principal_invariant_2  142 non-null    float64
#  42  avg_partial_charge_cyclohexane               142 non-null    float64
#  43  avg_partial_charge_dmso                      142 non-null    float64
#  44  avg_atomic_fukui_minus                       142 non-null    float64
#  45  avg_atomic_quadrupole_principal_invariant_3  142 non-null    float64
#  46  avg_atomic_fukui_plus                        142 non-null    float64
#  47  avg_partial_charge                           142 non-null    float64
#  48  avg_atomic_dipole_norm                       142 non-null    float64
#  49  avg_atomic_charge_dipole_interaction         142 non-null    float64
#  50  avg_bond_stiffness                           142 non-null    float64
#  51  avg_overlap_integral                         142 non-null    float64
#  52  avg_bond_length                              142 non-null    float64
#  53  avg_atomic_dipole_dipole_interaction         142 non-null    float64
#  54  avg_nuclear_repulsion                        142 non-null    float64
#  55  avg_atomic_charge_quadrupole_interaction     142 non-null    float64
#  56  avg_bond_energy                              0 non-null      float64
# dtypes: float64(55), int64(1), str(1)
# memory usage: 78.9 KB

# %%
null_df[null_df["sterimol_Bmax"].isna() & null_df["energy"].notna()]
# Out:
#      index        smiles    energy  atomization_energy  homo_lumo_gap  \
# 44    1266  [S:1]=[Fe:2] -6.290732            0.195666       0.009650
# 47    1308  [O:1]=[Mn:2] -6.779702            0.390915       0.047629
# 67    1645  [O:1]=[Co:2] -7.563763            0.286841       0.009911
# 175   8814   [O:1]=[Y:2] -5.217238            0.252253       0.047072
#
#      ionization_energy  electron_affinity  chemical_potential  \
# 44            0.423603           0.178285           -0.298930
# 47            0.457364           0.153677           -0.296536
# 67            0.492495           0.199619           -0.335602
# 175           0.539219           0.156817           -0.349591
#
#      molecular_dipole_norm  molecular_quadrupole_principal_invariant_2  ...  \
# 44                2.873166                                   -2.955365  ...
# 47                3.026655                                   -8.978168  ...
# 67                2.494365                                   -0.764242  ...
# 175               2.199255                                  -32.989183  ...
#
#      avg_partial_charge  avg_atomic_dipole_norm  \
# 44         1.000000e-10                0.558620
# 47         0.000000e+00                1.303515
# 67         0.000000e+00                0.683334
# 175       -0.000000e+00                0.206345
#
#      avg_atomic_charge_dipole_interaction  avg_bond_stiffness  \
# 44                               0.065998            0.503757
# 47                               0.140346            0.861228
# 67                               0.121129            0.879061
# 175                              0.029041            0.186508
#
#      avg_overlap_integral  avg_bond_length  \
# 44               0.559439         3.735073
# 47               0.450179         2.790336
# 67               0.461955         2.837714
# 175              0.346850         3.565589
#
#      avg_atomic_dipole_dipole_interaction  avg_nuclear_repulsion  \
# 44                               0.007325              58.937993
# 47                               0.250665              37.929284
# 67                               0.018588              40.279705
# 175                             -0.011236              46.304641
#
#      avg_atomic_charge_quadrupole_interaction  avg_bond_energy
# 44                                  -0.007910              NaN
# 47                                  -0.042319              NaN
# 67                                  -0.089018              NaN
# 175                                  0.107557              NaN
#
# [4 rows x 57 columns]

# %%
output_files_numbers[1645]
# Out:
# 2483

# %%
file_numbers = [output_files_numbers[idx] for idx in null_df["index"].to_list()]
file_numbers
# Out:
# [106,
#  1083,
#  1092,
#  1106,
#  1116,
#  114,
#  1167,
#  1184,
#  1198,
#  1218,
#  1245,
#  1259,
#  1272,
#  1274,
#  1276,
#  1278,
#  1280,
#  1282,
#  1286,
#  1291,
#  1292,
#  1300,
#  1305,
#  1325,
#  1333,
#  1343,
#  1344,
#  1355,
#  1396,
#  1406,
#  141,
#  1515,
#  1523,
#  154,
#  1572,
#  1707,
#  1807,
#  188,
#  1915,
#  1925,
#  1979,
#  1993,
#  2091,
#  2131,
#  2140,
#  2146,
#  2171,
#  2179,
#  2183,
#  2185,
#  2220,
#  2299,
#  2314,
#  2369,
#  2370,
#  2371,
#  2373,
#  2377,
#  2388,
#  2390,
#  2397,
#  2434,
#  2442,
#  2443,
#  2446,
#  2464,
#  247,
#  2483,
#  2501,
#  2504,
#  2510,
#  2515,
#  2531,
#  2543,
#  2550,
#  2567,
#  2577,
#  2578,
#  2591,
#  2592,
#  2593,
#  2698,
#  2702,
#  2703,
#  2704,
#  2785,
#  2786,
#  290,
#  2992,
#  3039,
#  3101,
#  3168,
#  3259,
#  3263,
#  3374,
#  3377,
#  346,
#  3471,
#  3570,
#  3575,
#  3612,
#  3700,
#  3825,
#  3841,
#  3897,
#  3899,
#  3903,
#  3930,
#  4324,
#  4334,
#  4347,
#  4349,
#  4350,
#  449,
#  456,
#  4574,
#  4705,
#  4799,
#  48,
#  485,
#  489,
#  5084,
#  5085,
#  5127,
#  5174,
#  5200,
#  5201,
#  5473,
#  5498,
#  5574,
#  5576,
#  5634,
#  5635,
#  5787,
#  5896,
#  5898,
#  5913,
#  5923,
#  5937,
#  6072,
#  6156,
#  620,
#  6297,
#  636,
#  645,
#  6455,
#  65,
#  656,
#  669,
#  676,
#  681,
#  687,
#  692,
#  6955,
#  736,
#  7403,
#  7434,
#  7435,
#  745,
#  7465,
#  7667,
#  7669,
#  769,
#  7754,
#  7843,
#  7947,
#  852,
#  8597,
#  8603,
#  8731,
#  8738,
#  8740,
#  8746,
#  8777,
#  882,
#  979,
#  99]

# %%
# null_df[null_df["index"]==158].info()

# %%
# for df in loader.stream_conformer_dataframe(OUTPUT_PATH / Path("internship_smiles2_114.json.gz")):
for df in loader.stream_conformer_dataframe(OUTPUT_PATH / Path("internship_smiles2_2483.json.gz")):
    tdf = df

# print(tdf.info())
tdf["bond_energy"]
# Out:
# 0    []
# Name: bond_energy, dtype: object

# %%
tdf[tdf.isnull().any(axis=1)].reset_index()
# Out:
# Empty DataFrame
# Columns: [index, energy, atomization_energy, homo_lumo_gap, ionization_energy, electron_affinity, chemical_potential, molecular_dipole, molecular_dipole_norm, molecular_quadrupole, molecular_quadrupole_principal_invariant_2, molecular_quadrupole_principal_invariant_3, molecular_polarizability, molecular_polarizability_mean, molecular_polarizability_anisotropy, normal_modes, normal_mode_frequencies, infrared_intensity, enthalpy, gibbs_free_energy, entropy, zero_point_energy, radius_of_gyration, molecular_volume, sterimol_L, sterimol_Bmin, sterimol_Bmax, molecular_sasa, heat_capacity, solvation_energy_water, solvation_energy_thf, solvation_energy_cyclohexane, solvation_energy_dmso, effective_coordination_number, partial_charge, atomic_fukui_minus, atomic_fukui_plus, atomic_dipole, atomic_dipole_norm, atomic_quadrupole, atomic_quadrupole_principal_invariant_2, atomic_quadrupole_principal_invariant_3, atomic_polarizability, atomic_polarizability_mean, atomic_polarizability_anisotropy, percentage_buried_volume, atomic_sasa, partial_charge_water, partial_charge_thf, partial_charge_cyclohexane, partial_charge_dmso, bond_energy, bond_length, bond_stiffness, overlap_integral, nuclear_repulsion, atomic_charge_dipole_interaction, atomic_charge_quadrupole_interaction, atomic_dipole_dipole_interaction, original_smiles, output_smiles]
# Index: []
#
# [0 rows x 61 columns]

# %%
engineer = QFPFeatureEngineer(300.0)
cleaned_tdf = engineer.clean_features(tdf)
aggregator = ConformerAggregator()
processed_tdf = aggregator.thermal_average(cleaned_tdf)

processed_tdf
# Out:
# C:\Users\thibo\OneDrive\Bureaublad\Enhancing-aqueous-solubility-prediction-models\ml_enhance\qfp_processing\feature_engineering.py:156: RuntimeWarning: Mean of empty slice
#   return np.array([x[2] for x in interaction_feature]).mean()
# c:\Users\thibo\OneDrive\Bureaublad\Enhancing-aqueous-solubility-prediction-models\.venv\Lib\site-packages\numpy\_core\_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# smiles                                         [O:1]=[Co:2]
# energy                                            -7.563763
# atomization_energy                                 0.286841
# homo_lumo_gap                                      0.009911
# ionization_energy                                  0.492495
# electron_affinity                                  0.199619
# chemical_potential                                -0.335602
# molecular_dipole_norm                              2.494365
# molecular_quadrupole_principal_invariant_2        -0.764242
# molecular_quadrupole_principal_invariant_3        -0.257155
# molecular_polarizability_mean                    -41.003243
# molecular_polarizability_anisotropy              592.809366
# enthalpy                                          -6.190301
# zero_point_energy                                  1.373461
# radius_of_gyration                                 0.504338
# molecular_volume                                 266.626638
# sterimol_L                                         5.021654
# sterimol_Bmin                                           2.0
# sterimol_Bmax                                           2.0
# molecular_sasa                                   283.513034
# solvation_energy_water                            -0.031634
# solvation_energy_thf                              -0.027032
# solvation_energy_cyclohexane                      -0.014617
# solvation_energy_dmso                             -0.031302
# gibbs_free_energy_300K                           -22.321846
# entropy_300K                                       0.053772
# heat_capacity_300K                                  0.00502
# ir_centroid_freq_1500                            960.748987
# ir_norm_intensity_1500                                  1.0
# ir_centroid_freq_1500_2750                              0.0
# ir_norm_intensity_1500_2750                             0.0
# ir_centroid_freq_2750_4000                              0.0
# ir_norm_intensity_2750_4000                             0.0
# avg_partial_charge                                      0.0
# avg_atomic_quadrupole_principal_invariant_2       -0.575545
# avg_partial_charge_cyclohexane                          0.0
# avg_atomic_polarizability_mean                   -18.042163
# avg_partial_charge_thf                                  0.0
# avg_effective_coordination_number                  0.988715
# avg_atomic_fukui_plus                                  -0.5
# avg_percentage_buried_volume                      23.999434
# avg_atomic_polarizability_anisotropy             880.284856
# avg_atomic_sasa                                  141.756517
# avg_partial_charge_dmso                                 0.0
# avg_atomic_quadrupole_principal_invariant_3       -0.222511
# avg_atomic_dipole_norm                             0.683334
# avg_atomic_fukui_minus                                 -0.5
# avg_partial_charge_water                                0.0
# avg_atomic_charge_quadrupole_interaction          -0.089018
# avg_atomic_charge_dipole_interaction               0.121129
# avg_bond_stiffness                                 0.879061
# avg_bond_energy                                         NaN
# avg_nuclear_repulsion                             40.279705
# avg_overlap_integral                               0.461955
# avg_atomic_dipole_dipole_interaction               0.018588
# avg_bond_length                                    2.837714
# dtype: object

# %% [markdown]
# In file 114, has empty bond_energy which leads to something wrong in the engineer

# %%
for t in loader.stream_conformer_dataframe(OUTPUT_PATH / "internship_smiles2_0.json.gz"):
    print(t["gibbs_free_energy"])
# Out:
# 0    [[200.0, 42.6861593912284], [300.0, 30.8223823...
# Name: gibbs_free_energy, dtype: object
