# %%
strange_one = df[df["molecular_quadrupole_principal_invariant_3"]==df["molecular_quadrupole_principal_invariant_3"].max()]

# %%
strange_one
# Out:
#                                                 smiles    id      energy  \
# 587  [O:1]([P:2]([O:3][H:42])(=[O:4])[C:5]([N:6]([C...  1539 -138.649438
#
#      atomization_energy  homo_lumo_gap  ionization_energy  electron_affinity  \
# 587            17.26368       0.158157          -0.112582          -0.414163
#
#      chemical_potential  molecular_dipole_norm  \
# 587            0.250917               4.086546
#
#      molecular_quadrupole_principal_invariant_2  ...  fr_sulfone  \
# 587                               -2.549393e+06  ...           0
#
#      fr_term_acetylene  fr_tetrazole  fr_thiazole  fr_thiocyan  fr_thiophene  \
# 587                  0             0            0            0             0
#
#      fr_unbrch_alkane  fr_urea  \
# 587                 6        0
#
#                                           canon_smiles  solubility
# 587  O=P(O)(O)CN(CCCCCCN(CP(=O)(O)O)CP(=O)(O)O)CCCC...   -0.087766
#
# [1 rows x 280 columns]

# %%
file = "data/QuantumFP/QFP_output/internship_smiles2_1539.json.gz"
from ml_enhance import QuantumFPFileLoader
from pathlib import Path
loader = QuantumFPFileLoader(Path("data/QuantumFP/QFP_output"))
for strange_df in loader.stream_conformer_dataframe(file):
    print(strange_df.info())
    print(strange_df["molecular_quadrupole_principal_invariant_3"])
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 61 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   id                                          17 non-null     Int64
#  1   original_smiles                             17 non-null     string
#  2   output_smiles                               17 non-null     string
#  3   energy                                      17 non-null     Float64
#  4   atomization_energy                          17 non-null     Float64
#  5   homo_lumo_gap                               17 non-null     Float64
#  6   ionization_energy                           17 non-null     Float64
#  7   electron_affinity                           17 non-null     Float64
#  8   chemical_potential                          17 non-null     Float64
#  9   molecular_dipole                            17 non-null     object
# ...

# %%
Chem.MolFromSmiles('O=P(O)(O)CN(CCCCCCN(CP(=O)(O)O)CP(=O)(O)O)CCCCCCN(CP(=O)(O)O)CP(=O)(O)O')

# %%
df.nlargest(10, "molecular_quadrupole_principal_invariant_3")[['id', 'molecular_quadrupole_principal_invariant_3', 'canon_smiles']]
# Out:
#         id  molecular_quadrupole_principal_invariant_3  \
# 587   1539                                1.561343e+09
# 1657  2529                                1.543235e+08
# 3949  4610                                7.055779e+07
# 96    1088                                4.600046e+07
# 6969  7337                                4.160781e+07
# 1590  2465                                3.977570e+07
# 2999  3748                                3.447213e+07
# 2997  3746                                3.447213e+07
# 7001  7367                                3.429472e+07
# 7012  7376                                2.534992e+07
#
#                                            canon_smiles
# 587   O=P(O)(O)CN(CCCCCCN(CP(=O)(O)O)CP(=O)(O)O)CCCC...
# 1657  O=C(N=NNc1cc(Cl)c(-c2ccc(-c3cc(Cl)c(NN=NC(=O)c...
# 3949  O=P(O)(O)CN(CCCCCCN(CP(=O)(O)O)CP(=O)(O)O)CP(=...
# 96    N=NN=NC1=CCc2c(cccc2S(=O)(=O)Oc2ccc(C(=O)c3ccc...
# 6969  Nc1nc(=O)c2nc(CNc3ccc(C(=O)NC(CCC(=O)O)C(=O)O)...
# ...

# %%
df.nsmallest(60, "molecular_quadrupole_principal_invariant_2")[['id', 'molecular_quadrupole_principal_invariant_2', "canon_smiles"]]
# Out:
#         id  molecular_quadrupole_principal_invariant_2  \
# 587   1539                               -2.549393e+06
# 1657  2529                               -5.410584e+05
# 3949  4610                               -3.286044e+05
# 96    1088                               -2.452805e+05
# 6969  7337                               -2.284173e+05
# 7001  7367                               -2.263312e+05
# 2999  3748                               -2.190402e+05
# 2997  3746                               -2.190402e+05
# 1590  2465                               -2.148700e+05
# 8704   944                               -1.931913e+05
# 7012  7376                               -1.647344e+05
# 1612  2486                               -1.543299e+05
# 1424  2304                               -1.501184e+05
# 1541  2418                               -1.355081e+05
# 8632  8838                               -1.342980e+05
# 4055  4706                               -1.327150e+05
# ...

# %%
strange_smiles = df.nsmallest(10, "molecular_quadrupole_principal_invariant_2")['canon_smiles']

# %%
from rdkit.Chem import Draw

imgs = []
for smiles in strange_smiles:
    mol = Chem.MolFromSmiles(smiles)
    img = Draw.MolToImage(mol)
    imgs.append(img)

# %%
imgs[]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
print(X["molecular_quadrupole_principal_invariant_3"].min())
print(X["molecular_quadrupole_principal_invariant_3"].max())
# Out:
# -22651023.575952195
# 1561343174.1536963

# %%
strange_one = df[df["molecular_quadrupole_principal_invariant_2"]==df["molecular_quadrupole_principal_invariant_2"].min()]

# %%
strange_one
# Out:
#                                                 smiles    id      energy  \
# 587  [O:1]([P:2]([O:3][H:42])(=[O:4])[C:5]([N:6]([C...  1539 -138.649438
#
#      atomization_energy  homo_lumo_gap  ionization_energy  electron_affinity  \
# 587            17.26368       0.158157          -0.112582          -0.414163
#
#      chemical_potential  molecular_dipole_norm  \
# 587            0.250917               4.086546
#
#      molecular_quadrupole_principal_invariant_2  ...  fr_sulfone  \
# 587                               -2.549393e+06  ...           0
#
#      fr_term_acetylene  fr_tetrazole  fr_thiazole  fr_thiocyan  fr_thiophene  \
# 587                  0             0            0            0             0
#
#      fr_unbrch_alkane  fr_urea  \
# 587                 6        0
#
#                                           canon_smiles  solubility
# 587  O=P(O)(O)CN(CCCCCCN(CP(=O)(O)O)CP(=O)(O)O)CCCC...   -0.087766
#
# [1 rows x 280 columns]

# %%
Chem.MolFromSmiles('O=P(O)(O)CN(CCCCCCN(CP(=O)(O)O)CP(=O)(O)O)CCCCCCN(CP(=O)(O)O)CP(=O)(O)O')

# %%
strange_one = df[df["molecular_polarizability_anisotropy"]==df["molecular_polarizability_anisotropy"].max()]

# %%
strange_one["canon_smiles"].to_numpy()
# Out:
# array(['CCCCCCCC/C=C/CCCCCCCCO[P+](=O)OCCCCCCCC/C=C/CCCCCCCC'],
#       dtype=object)

# %%
Chem.MolFromSmiles('CCCCCCCC/C=C/CCCCCCCCO[P+](=O)OCCCCCCCC/C=C/CCCCCCCC')
